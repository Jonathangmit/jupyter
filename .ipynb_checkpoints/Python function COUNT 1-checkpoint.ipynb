# %% [markdown]
# ### Jonathan Harper
# ### Fundamentals of data analysis:
#
# ***
#
# ## The references stated below are references used in the in the contruction of the counts  assignment
#
# [1]Stack overflow;
#     https://stackoverflow.com/questions/40284484/count-or-add-list-elements-without-using-python-built-in-functions
#
# [2]An informal introduction to python; https://docs.python.org/3/tutorial/introduction.html#lists
#
# [3]Geeks for geeks; https://www.geeksforgeeks.org/python-count-occurrences-of-a-character-in-string/
#
# [4]Geeks for geeks; https://www.geeksforgeeks.org/python-frequency-of-each-character-in-string/
#
# [5]python.org; https://wiki.python.org/moin/ForLoop

# %% [markdown]
# ***
#
# # Assignment 1 Count

# %% [markdown]
# ## practice
#
# ###### I wanted first to establish the mechanism which was going to count my letters and be confident that this would indeed count the individual discrete items and provide the required output before wrapping it in a function. This code clearly does that.

# %%
# asking the user for a list of words in which individual characters are 
# counted and the values foreach character returned.

# requesting the list
x=str(input("please enter a sentence:"))
count = {}
for i in x: 
    if i in count: 
        count[i] +=1
    else:
        count[i] = 1
    
print (count)
# Out:
# please enter a sentence:hello
# {'h': 1, 'e': 1, 'l': 2, 'o': 1}

# %%
#practice area to inroduce function
x=str(input("please enter a sentence:"))
y = {}
def count (x):
    for i in x: 
        if i in y: 
            y[i] +=1
        else:
            y[i] = 1
    return y
print (count(x))
# Out:
# please enter a sentence:hello
# {'h': 1, 'e': 1, 'l': 2, 'o': 1}

# %% [markdown]
# ***
# ## Count Assignment code

# %%
#Move from input to list as requested
x=['A','A','B','C','A']
#creating the dictionary y in which the counts will be stored
y = {}
def count (n): #Naming the function count
    for i in n: #Function now looks for a character from the list
        if i in y: 
            y[i] += 1  # If character is already counted once then 1 more is added to the count
        else:
            y[i] = 1 # if character encountered for the first time then the count is 1
    return y 
print (count(x))#the function is called for the list x here
# Out:
# {'A': 3, 'B': 1, 'C': 1}

# %% [markdown]
# ***
# ### I have taken the code for assignment and manipulated it to develop my understanding.

# %%
x=['A','A','B','C','A']
y = {}
def count (n): 
    for i in n: 
        if i in y: 
            y[i] += 1  
        else:
            y[i] = 1
        print (y) #added a print statement here to display every iteration of the list
    return y
print('After consulting my dictionary I can announce the count for each character in the list is as follows','\n',count(x))
# Out:
# {'1': 1}
# {'1': 1, 'A': 1}
# {'1': 1, 'A': 1, 'B': 1}
# {'1': 1, 'A': 1, 'B': 1, 'C': 1}
# {'1': 1, 'A': 2, 'B': 1, 'C': 1}
# After consulting my dictionary I can announce the count for each character in the list is as follows
#  {'1': 1, 'A': 2, 'B': 1, 'C': 1}

# %% [markdown]
# #### In the above code I have simply taken the assignment code and added a print statement within the for loop, this is interesting in that it allows us to see the dictionary formed with each interation of the loop.
#
# * The first letter encountered is A, A is assigned a value of 1 through the else statement.
# * The second leter encountered is A therefore the count for A has 1 added (A=2) to it through the if statement.
# * The third letter encountered is B,  B is assigned a value of 1 through the else statement.
# * The fourth letter encountered is C, C is assigned a value of 1 through the else statement.
# * The fifth leter encountered is A therefore the count for A has 1 added (A=3) to it through the if statement.

# %%
#Now we have 2 lists x and z
x=['A','A','B','C','A']
z=['D','E','F','F','F']
def count(n) : #ensuring the function is clearly generic by removing the label.
    y = {} # by moving the dictionary creation into the loop we clear it everytime we call the function.
    for i in n:
        if i in y: 
            y[i] +=1
        else:
            y[i] = 1
    return y
print ('x dictionary:',(count(x)))# this will give us our first list
print ('z dictionary:',(count(z)))# this will give us our second list
print ('x and z dictionarys combined:',(count(x + z))) #this combines both lists
# Out:
# x dictionary: {'A': 3, 'B': 1, 'C': 1}
# z dictionary: {'D': 1, 'E': 1, 'F': 3}
# x and z dictionarys combined: {'A': 3, 'B': 1, 'C': 1, 'D': 1, 'E': 1, 'F': 3}

# %% [markdown]
# ###### In this code I have added a second list to demonstrate that the created function will run on different lists and that by calling the fuction correctly both lists can be placed into the same dictionary by the same function.
#
# ###### In order to achive separate outputs for each list in code that called for the fuction onboth lists I had to create the dictionary inside the function, thus the dictionary was cleared of list x before executing list z. I also called the function with the lists combined and (x+z) . This achived the desired output of both lists being assigned to the same dictionary.
# ***
# ###### End of Counts
# ***

# %% [markdown]
# # Assignment 2 Dice
#
# ###### The references stated below are references used in the in the contruction of the dice assignment
#
# ###### How to put a loop output into a list; https://stackoverflow.com/questions/39322625/how-to-put-python-loop-output-in-a-list/39323039
# ###### sorting dictionarys by key ; https://stackoverflow.com/questions/9001509/how-can-i-sort-a-dictionary-by-key
# ###### Sorting dictionarys by value ;https://stackoverflow.com/questions/613183/how-do-i-sort-a-dictionary-by-value
#
# ##### The most pleasing thing about this assignment was that I was able to go deep into the programme before having to source help from outside (internet). I immediately saw what I had to do in terms of writing to a list and then placing that list into the count function or something approching it. It marked a turning point for me , although I found it difficult I had the plan in my head and perhaps more so when I did go to the internet I was looking for syntax more than the full idea.

# %%
# create the 2 dice rolls
import numpy as np
rng = np.random.default_rng()
d1 = rng.integers(1,6,endpoint=True)
d2 = rng.integers(1,6,endpoint=True)
print("First dice rolls")
print(d1) 
print("Second dice rolls")
print(d2)
print("total is")
print(d1+d2)
# Out:
# First dice rolls
# 3
# Second dice rolls
# 5
# total is
# 8

# %%
### Create multiple dice rolls
import sys
import numpy as np
rng = np.random.default_rng()
k = int(input("how many dice do you want?"))
n = int(input("how many times shall I roll?"))

def dicerolls(k,n):
    b=1
    while b <=n:
        a=1
        rolls=0
        print('roll',b)
        while a <=k:
            dice = rng.integers(1,6,endpoint=True)
            print (dice)
            rolls = (rolls + dice)
            a = a+1
        b=b+1
        print("total",(rolls))
    return

dicerolls(k,n)
print('end')
# Out:
# how many dice do you want?3
# how many times shall I roll?3
# roll 1
# 3
# 4
# 2
# total 9
# roll 2
# 5
# 5
# 1
# total 11
# roll 3
# 6
# 1
# 4
# total 11
# end

# %% [markdown]
# ***
# ## Dice assignment code

# %%
#import packages
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import operator

#Generating inputs and list
rng = np.random.default_rng()
k = int(input("how many dice do you want?"))
n = int(input("how many times shall I roll?"))
q=[]
def dicerolls(k,n):
    b=1
    while b <=n:
        a=1
        rolls=0
        #print('roll',b) used to track my programming
        while a <=k:
            dice = rng.integers(1,6,endpoint=True)
            #print (dice)
            rolls = (rolls + dice)
            a = a+1
        b=b+1
        #print(rolls)used to track my programming
        q.append(int(rolls))
        #print(q)used to track my programming
    return
y ={}
def count (j): #Naming the function count
    for i in (j): #Function now looks for a character from the list
        if i in y: 
            y[i] += 1  # If character is already counted once then 1 more is added to the count
        else:
            y[i] = 1 # if character encountered for the first time then the count is 1
    return y
dicerolls(k,n)#calling the dice rolls to list q
count(q)#calling count function on the list

print ("The number of dice you wanted was",(k),"the number of rolls you wanted was",(n) ,
       " Ive counted the \ntotals for each over all value and here they are....",)

#creating the ordered output
sorted_y = sorted(y.items(), key=operator.itemgetter(0))
print(sorted_y)
sns.set(rc={'figure.figsize':(12,9)})
sns.histplot(q,bins=((6*k)-(k-1)))
plt.show()
print('end')
# Out:
# how many dice do you want?2
# how many times shall I roll?100
# The number of dice you wanted was 2 the number of rolls you wanted was 100  Ive counted the
# totals for each over all value and here they are....
# [(2, 3), (3, 7), (4, 8), (5, 14), (6, 9), (7, 17), (8, 16), (9, 9), (10, 5), (11, 8), (12, 4)]
# end

# %% [markdown]
# ***

# %% [markdown]
# # Assignment 3 Numpy random Binomial

# %% [markdown]
# ###### The references stated below are references used in the in the contruction of the counts assignment
#
# ###### [1] Stack overflow; https://numpy.org/doc/stable/reference/random/generated/numpy.random.binomial.html

# %% [markdown]
# ###### In previous commits there is some attempts to solve this problem, the code below was found looking at the binomial page in NumPy. I relaised that the soloution was there with the probability set to 0.5 and the number of flips per round set to 100. I was able to then place these values into a seaborn histogram

# %% [markdown]
# ***
# ## Numpy random binomial assignment code

# %%
#import packages
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
rng = np.random.default_rng()
n, p = 100, .5 
#setting the coin toss 
s = rng.binomial(n, p, 1000)
sns.set(rc={'figure.figsize':(12,9)})
print(s)
#creating visual output
plt.title("100 tosses of a coin, 1000 times", fontdict=None, loc='center', pad=None)
sns.histplot(s,binwidth = 1)
plt.xlabel("total number of heads")
plt.ylabel("number of instances")
# Out:
# [50 50 49 45 49 46 52 48 44 46 50 48 46 50 51 52 49 54 49 49 49 54 49 42
#  51 51 53 42 52 50 43 52 47 57 46 51 47 51 49 53 50 53 45 49 46 53 48 45
#  51 51 44 44 53 51 49 59 54 48 47 55 50 42 45 62 52 46 58 49 48 46 45 36
#  51 56 44 50 48 51 53 42 46 53 48 43 56 56 47 48 51 52 49 49 57 57 51 50
#  58 46 42 40 55 48 51 47 54 52 50 47 52 57 53 45 46 48 53 55 54 54 49 49
#  51 42 53 43 54 47 59 49 49 55 58 52 57 48 45 54 52 53 53 46 55 42 57 56
#  54 47 49 55 44 46 55 42 44 48 50 51 54 50 51 53 53 56 43 54 51 58 57 49
#  43 57 54 50 47 55 49 48 51 48 47 55 50 48 50 52 47 55 50 50 42 62 56 46
#  48 39 52 62 55 53 52 57 50 45 55 37 67 58 55 52 41 53 54 46 48 34 52 52
#  46 50 45 45 53 51 48 50 56 51 52 48 54 51 48 55 44 56 42 52 45 53 50 41
#  45 54 46 56 52 51 50 46 56 51 56 51 63 55 53 57 55 47 56 54 52 45 47 45
#  46 53 53 55 53 50 48 61 54 53 44 56 50 45 48 42 52 59 41 47 44 46 49 45
#  43 46 48 54 45 50 42 50 50 55 56 49 55 45 53 50 47 53 43 54 45 57 53 51
#  48 50 57 54 55 49 43 38 49 45 45 56 49 48 55 44 46 46 53 44 43 52 45 52
#  53 48 59 57 49 52 47 42 48 50 48 48 58 50 50 50 57 48 50 50 47 54 57 49
#  53 48 57 52 49 57 50 51 49 45 47 45 56 49 55 45 51 52 48 53 58 55 60 55
#  53 50 53 64 40 57 52 51 50 53 39 54 46 44 43 53 44 40 53 56 56 53 48 50
#  57 54 52 55 51 44 50 53 55 48 52 58 49 47 47 49 38 60 47 52 49 47 40 54
#  57 55 43 58 54 51 44 52 43 55 38 48 54 41 47 55 60 53 59 53 56 52 59 55
#  48 48 52 40 45 55 46 49 55 53 56 49 53 50 40 56 50 45 57 44 42 50 58 47
#  50 54 53 46 48 49 58 48 54 54 50 54 56 52 43 49 46 41 48 51 51 44 50 57
#  49 54 47 52 41 44 56 52 52 57 48 53 46 50 52 54 56 58 49 56 53 48 44 52
#  54 51 50 40 48 51 50 56 51 52 47 57 57 55 51 55 50 54 38 51 53 49 53 36
#  46 53 49 45 51 50 57 52 49 40 51 50 44 40 50 50 49 45 39 46 50 56 46 56
#  52 49 56 58 47 57 42 47 48 48 45 55 46 54 56 54 49 51 56 56 52 46 43 50
#  55 46 46 46 44 50 51 49 44 36 49 49 55 53 57 45 45 50 51 49 45 46 52 52
#  52 53 51 44 57 54 49 54 50 51 42 43 45 42 49 47 50 45 54 55 50 47 41 48
#  57 58 57 56 47 50 52 55 55 42 50 45 48 47 55 59 43 48 47 49 53 51 47 49
#  48 50 47 50 52 43 54 50 49 50 47 52 48 45 46 55 48 54 54 62 57 55 39 59
#  51 62 46 52 51 56 51 48 47 57 50 54 58 49 56 51 42 48 48 52 38 58 50 51
#  45 51 50 51 52 45 54 51 54 50 44 40 48 54 61 53 49 52 50 46 59 51 42 52
#  47 47 63 52 43 48 51 57 42 48 47 41 48 47 51 45 45 60 45 51 51 48 42 49
#  48 50 42 51 46 56 49 57 55 54 52 44 48 55 48 53 41 51 55 42 53 52 45 48
#  44 51 46 43 54 58 55 49 52 39 56 48 47 50 47 50 49 51 54 46 46 37 59 51
#  59 59 50 54 50 51 56 49 51 52 47 43 61 52 42 50 45 58 40 44 51 49 55 43
#  52 47 44 55 50 57 52 41 47 47 48 45 58 53 50 40 50 46 57 43 55 53 47 44
#  50 56 48 52 53 49 59 57 49 54 51 48 49 56 55 53 46 41 55 47 47 50 48 61
#  44 57 51 49 46 38 37 42 48 49 57 52 52 48 48 53 59 47 60 45 50 54 57 53
#  44 41 54 55 48 48 54 50 49 44 47 53 57 52 46 54 47 49 51 58 57 51 51 43
#  54 45 50 45 53 49 46 49 54 44 55 40 48 44 45 46 56 49 47 59 55 53 42 54
#  49 52 51 56 53 54 48 49 52 44 52 54 56 54 46 46 49 49 54 55 55 49 55 46
#  60 53 47 51 54 54 49 48 56 48 51 48 50 46 51 54]
# Text(0, 0.5, 'number of instances')

# %% [markdown]
# ***

# %% [markdown]
# # Assignment 4 Simpson's Paradox

# %% [markdown]
# ###### The references stated below are references used in the in the contruction of the dice assignment
# ###### [1]Stack overflow; https://en.wikipedia.org/wiki/Simpson%27s_paradox#:~:text=Simpson's%20paradox%2C%20which%20also%20goes,when%20these%20groups%20are%20combined.
# ###### [2] Matplotlib manipulations; https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.title.html

# %%
#Re creating the values used for the small/large kidney stones to check the programe on.

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(1.0, 87.0, num=87)
y = 0.93*x+0

x1 = np.linspace(1.0, 270.0, num=270)
y1 = 0.87*(x1)+0

x2 = np.linspace(1.0, 263.0, num=263)
y2 = 0.73*(x2)+0

x3 = np.linspace(1.0, 80.0, num=80)
y3 = 0.69*(x3)+0

x4 = np.linspace(1.0, 273.0, num=80)
y4 = 0.78*(x4)+0

x5 = np.linspace(1.0, 350.0, num=80)
y5 = 0.83*(x5)+0

plt.style.use('ggplot')
plt.rcParams['figure.figsize']=14,10
plt.plot(x,y,'y-',label = "A small")
plt.plot(x1,y1,'b-',label = "B small")
plt.plot(x2,y2,'y-',label = "A Large")
plt.plot(x3,y3,'b-',label = "B Large")
plt.plot(x4,y4,'r-',label = "A Both")
plt.plot(x5,y5,'g-',label = "B both")
plt.legend()
plt.show()

# %%
# The baseball example

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(1.0, 48.0, num=48)
y = 0.25*x+0

x1 = np.linspace(1.0, 411.0, num=411)
y1 = 0.253*(x1)+0

x2 = np.linspace(1.0, 582.0, num=582)
y2 = 0.314*(x2)+0

x3 = np.linspace(1.0, 140.0, num=140)
y3 = 0.321*(x3)+0

x4 = np.linspace(1.0, 630.0, num=630)
y4 = 0.310*(x4)+0

x5 = np.linspace(1.0, 551.0, num=551)
y5 = 0.270*(x5)+0

plt.style.use('ggplot')
plt.rcParams['figure.figsize']=14,10
plt.plot(x,y,'y-',label = "A small")
plt.plot(x1,y1,'b-',label = "B small")
plt.plot(x2,y2,'y-',label = "A Large")
plt.plot(x3,y3,'b-',label = "B Large")
plt.plot(x4,y4,'r-',label = "A Both")
plt.plot(x5,y5,'g-',label = "B both")
plt.legend()
plt.show()

# %% [markdown]
# ***
# ## Simpson's Paradox assignment code
#
# ###### In this I wanted set up the code that I could pass different values until I had generated a set of my own values that give the sompson Paradox. From there I was able to play with the number slightly to see the difference it made.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set my varyables
n=60
n1=210
n2=195
n3=55
g=0.89
g1=0.83
g2=0.71
g3=0.65
#generating the code to take in the values determined by me
x = np.linspace(1.0, n, num=n)
y = g*x+0

x1 = np.linspace(1.0, n1, num=n1)
y1 = g1*(x1)+0

x2 = np.linspace(1.0, n2, num=n2)
y2 = g2*(x2)+0

x3 = np.linspace(1.0, n3, num=n3)
y3 = g3*(x3)+0

# Generating the values for each combined set ( n and n2, n1 and n3)
x4 = np.linspace(1.0, (n + n2), num=(n + n2))
y4 = (((n*g)+(n2*g2))/(n+n2))*(x4)+0

x5 = np.linspace(1.0, (n1+n3), num=(n1+n3))
y5 = (((n1*g1)+(n3*g3))/(n1+n3))*(x5)+0

#obtaining gradients of combines lines
j=(((n*g)+(n2*g2))/(n+n2))
k=(((n1*g1)+(n3*g3))/(n1+n3))

#Displaying the values used in the final graph
print("GROUP A1 x=",g,"n=", n)
print("GROUP B1  x=",g1,"n=", n1)
print("Group A2 x=",g2,"n=", n2)
print("Group B2=",g3,"n=", n3)
print("Group A1+2 x=",round(j,2),"n=", (n+n2))
print("Group B1+2 x=",round(k,2),"n=",(n1+n3))

#Generating visual output
plt.style.use('ggplot')
plt.rcParams['figure.figsize']=14,10
plt.plot(x,y,'b-',label = "A small")#Drawing respective graphs
plt.plot(x1,y1,'g-',label = "B small")
plt.plot(x2,y2,'r-',label = "A Large")
plt.plot(x3,y3,'y-',label = "B Large")
plt.plot(x4,y4,'k-',label = "A Both")
plt.plot(x5,y5,'w-',label = "B both")
plt.title("Simpson's paradox using own values", fontdict=None, loc='center', pad=None)#Setting up the graph
plt.xlabel("x values")
plt.ylabel("y values")
plt.legend()
plt.show()
# Out:
# GROUP A1 x= 0.89 n= 60
# GROUP B1  x= 0.83 n= 210
# Group A2 x= 0.71 n= 195
# Group B2= 0.65 n= 55
# Group A1+2 x= 0.75 n= 255
# Group B1+2 x= 0.79 n= 265
